# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
from scipy.stats import norm

# %% [markdown]
# ### change the filename depending on what is needed - variable names not yet generic

# %%
all_train_data = pd.read_csv("c:/Users/Rachel/Documents/Grad_Stuff/Dissertation/degree3_train_normspkrmean_legens.csv")

# %%
all_train_data
# Out:
#       Unnamed: 0                file   ID  language       start questions  \
# 0              0  p254p255-part1_ch2  255   English    5.889176        WH
# 1              1  p254p255-part1_ch2  255   English   26.446841       Y/N
# 2              2  p254p255-part1_ch2  255   English   30.233468        WH
# 3              3  p254p255-part1_ch2  255   English   48.636714        WH
# 4              4  p254p255-part1_ch2  255   English  104.758627        WH
# 5              5  p254p255-part1_ch2  255   English  118.306289       Y/N
# 6              6  p254p255-part1_ch2  255   English  142.635380       Y/N
# 7              7  p254p255-part1_ch2  255   English  152.205946       Y/N
# 8              8  p254p255-part1_ch2  255   English  211.408755       Y/N
# 9              9  p254p255-part1_ch2  255   English  284.433922        WH
# 10            10  p254p255-part1_ch2  255   English  290.516178        WH
# 11            11  p254p255-part1_ch2  255   English  305.194943        WH
# 12            12  p254p255-part1_ch2  255   English  308.530373       Y/N
# 13            13  p254p255-part1_ch2  255   English  363.860604       Y/N
# 14            14  p254p255-part1_ch2  255   English  370.603639        WH
# 15            15  p254p255-part1_ch2  255   English  381.585251       Y/N
# 16            16  p254p255-part1_ch2  255   English  416.171533       Y/N
# 17            17  p254p255-part1_ch2  255   English  434.355349       Y/N
# 18            18  p254p255-part1_ch2  255   English  444.158805       Y/N
# 19            19  p254p255-part1_ch2  255   English  450.868906       Y/N
# 20            20  p254p255-part1_ch2  255   English  463.436278        WH
# 21            21  p254p255-part1_ch2  255   English  543.697132        WH
# 22            22  p254p255-part1_ch2  255   English  602.585570       Y/N
# 23            23  p254p255-part1_ch2  255   English  647.653809       Y/N
# 24            24  p254p255-part1_ch2  255   English  700.244484        WH
# 25            25  p254p255-part1_ch2  255   English  759.700644       Y/N
# 26            26  p254p255-part1_ch2  255   English  763.762020       Y/N
# 27            27  p254p255-part1_ch2  255   English  862.826277        WH
# 28            28  p254p255-part1_ch2  255   English  910.405556       Y/N
# 29            29  p254p255-part1_ch2  255   English  916.984339        WH
# ...          ...                 ...  ...       ...         ...       ...
# 1374        1374  p442p443-part2_ch1  443  Mandarin    4.710524        WH
# 1375        1375  p442p443-part2_ch1  443  Mandarin   25.115266        WH
# 1376        1376  p442p443-part2_ch1  443  Mandarin   39.326081        WH
# 1377        1377  p442p443-part2_ch1  443  Mandarin   60.675249        WH
# 1378        1378  p442p443-part2_ch1  443  Mandarin   98.540140       Y/N
# 1379        1379  p442p443-part2_ch1  443  Mandarin  104.143052       Y/N
# 1380        1380  p442p443-part2_ch1  443  Mandarin  121.337392       Y/N
# 1381        1381  p442p443-part2_ch1  443  Mandarin  147.162601       Y/N
# 1382        1382  p442p443-part2_ch1  443  Mandarin  156.444755       Y/N
# 1383        1383  p442p443-part2_ch1  443  Mandarin  202.105153       Y/N
# 1384        1384  p442p443-part2_ch1  443  Mandarin  217.185267       Y/N
# 1385        1385  p442p443-part2_ch1  443  Mandarin  228.358894        WH
# 1386        1386  p442p443-part2_ch1  443  Mandarin  248.945331       Y/N
# 1387        1387  p442p443-part2_ch1  443  Mandarin  254.242754        WH
# 1388        1388  p442p443-part2_ch1  443  Mandarin  265.802737        WH
# 1389        1389  p442p443-part2_ch1  443  Mandarin  291.047660        WH
# 1390        1390  p442p443-part2_ch1  443  Mandarin  301.910056        WH
# 1391        1391  p442p443-part2_ch1  443  Mandarin  309.702318        WH
# 1392        1392  p442p443-part2_ch1  443  Mandarin  326.564714        WH
# 1393        1393  p442p443-part2_ch1  443  Mandarin  344.028108       Y/N
# 1394        1394  p442p443-part2_ch1  443  Mandarin  350.264214       Y/N
# 1395        1395  p442p443-part2_ch1  443  Mandarin  362.886676       Y/N
# 1396        1396  p442p443-part2_ch1  443  Mandarin  372.375362        WH
# 1397        1397  p442p443-part2_ch1  443  Mandarin  380.392998       Y/N
# 1398        1398  p442p443-part2_ch1  443  Mandarin  389.301400        WH
# 1399        1399  p442p443-part2_ch1  443  Mandarin  402.547075       Y/N
# 1400        1400  p442p443-part2_ch1  443  Mandarin  411.015460       Y/N
# 1401        1401  p442p443-part2_ch1  443  Mandarin  424.099402       Y/N
# 1402        1402  p442p443-part2_ch1  443  Mandarin  432.671366       Y/N
# 1403        1403  p442p443-part2_ch1  443  Mandarin  441.226359       Y/N
#
#           means       stds                                            f0final  \
# 0     88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -0....
# 1     88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# 2     88.891661  58.743472  [0.20412887421808237, 0.27275777704594406, 0.3...
# 3     88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# 4     88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# 5     88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# 6     88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# 7     88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# 8     88.891661  58.743472  [-1.5132177067301742, -0.08958052953474949, -0...
# 9     88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# 10    88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# 11    88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# 12    88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# 13    88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# 14    88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# 15    88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# 16    88.891661  58.743472  [-0.5949154922539469, -0.503412217775867, -0.4...
# 17    88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# 18    88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# 19    88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# 20    88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# 21    88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# 22    88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# 23    88.891661  58.743472  [-0.11968906676743776, -0.11869355188777174, -...
# 24    88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# 25    88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# 26    88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# 27    88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# 28    88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# 29    88.891661  58.743472  [-1.5132177067301742, -1.5132177067301742, -1....
# ...         ...        ...                                                ...
# 1374  85.374737  58.059220  [-1.4704768208960772, -1.4704768208960772, -1....
# 1375  85.374737  58.059220  [-1.4704768208960772, -1.4704768208960772, -1....
# 1376  85.374737  58.059220  [-1.4704768208960772, -1.4704768208960772, -1....
# 1377  85.374737  58.059220  [0.8803591144098241, 0.8713011215036697, 0.858...
# 1378  85.374737  58.059220  [-0.16974404467219706, -0.13793962135801022, -...
# 1379  85.374737  58.059220  [-1.4704768208960772, -1.4704768208960772, -1....
# 1380  85.374737  58.059220  [-1.4704768208960772, -0.592564746280385, -0.6...
# 1381  85.374737  58.059220  [-1.4704768208960772, -1.4704768208960772, -1....
# 1382  85.374737  58.059220  [-1.4704768208960772, -1.4704768208960772, -1....
# 1383  85.374737  58.059220  [-1.4704768208960772, -1.4704768208960772, -1....
# 1384  85.374737  58.059220  [-1.4704768208960772, -1.4704768208960772, -1....
# 1385  85.374737  58.059220  [-1.4704768208960772, -1.4704768208960772, -1....
# 1386  85.374737  58.059220  [-1.4704768208960772, -1.4704768208960772, -1....
# 1387  85.374737  58.059220  [-1.4704768208960772, -1.4704768208960772, -1....
# 1388  85.374737  58.059220  [-1.4704768208960772, -1.4704768208960772, -1....
# 1389  85.374737  58.059220  [-1.4704768208960772, -1.4704768208960772, -1....
# 1390  85.374737  58.059220  [0.9318186417072544, 0.9332998879326379, 0.932...
# 1391  85.374737  58.059220  [0.4523960770684903, 0.45336749901164886, 0.44...
# 1392  85.374737  58.059220  [-1.4704768208960772, -1.4704768208960772, -1....
# 1393  85.374737  58.059220  [-1.4704768208960772, -1.4704768208960772, -1....
# 1394  85.374737  58.059220  [0.2556779664408711, -0.10675973278954888, -0....
# 1395  85.374737  58.059220  [-1.4704768208960772, -1.4704768208960772, 0.8...
# 1396  85.374737  58.059220  [-1.4704768208960772, -1.4704768208960772, -1....
# 1397  85.374737  58.059220  [-1.4704768208960772, -1.4704768208960772, -1....
# 1398  85.374737  58.059220  [-1.4704768208960772, -1.4704768208960772, 0.7...
# 1399  85.374737  58.059220  [-1.4704768208960772, -1.4704768208960772, 0.7...
# 1400  85.374737  58.059220  [-1.4704768208960772, -1.4704768208960772, -1....
# 1401  85.374737  58.059220  [-1.4704768208960772, -1.4704768208960772, -1....
# 1402  85.374737  58.059220  [-1.4704768208960772, -1.4704768208960772, -1....
# 1403  85.374737  58.059220  [-1.4704768208960772, -1.4704768208960772, -0....
#
#                                             legen_coefs
# 0     [0.4388430287752368, -0.48455826443425853, -1....
# 1     [0.4500430535993323, 0.47647529241271597, -0.4...
# 2     [-0.10337883280469173, -0.793930796883687, 0.2...
# 3     [-0.06987262342204603, 0.40040356082189654, 0....
# 4     [0.21089670261937551, -0.4737557421398777, -0....
# 5     [-0.13401660966352277, 0.25877110895968375, -0...
# 6     [-0.1518519043292215, -0.5242963911182915, -0....
# 7     [-0.2924882523584111, -0.17550195714455066, -1...
# 8     [0.20993341108827804, 0.06132486451460317, -0....
# 9     [-0.28721908553079384, 0.18532774117872916, -0...
# 10    [-0.05031777818458314, 0.06080103069003462, -0...
# 11    [0.005245964517783691, 0.5293642891017979, -1....
# 12    [-0.5046190732051637, 0.06373237075582265, -0....
# 13    [0.10947245109731464, 0.9099846247410296, 1.12...
# 14    [0.41195271528725314, 0.20093293946595112, -1....
# 15    [0.0683656969925309, 0.07190313948854432, -0.9...
# 16    [0.24968131914861377, 0.48501659965308247, -0....
# 17    [0.12744629037834698, 0.04478697810406636, -1....
# 18    [-0.5602470437977679, 0.28361854440683737, -0....
# 19    [0.2667927354672823, 0.23631548628810647, -0.7...
# 20    [-0.4206667260789108, -0.025066959704998098, -...
# 21    [0.13598688953663154, -0.6098438273630411, -0....
# 22    [0.6341619027194905, 0.14137636437284268, -1.2...
# 23    [0.32614077471164843, 0.07428266324105313, -1....
# 24    [0.8515263663937654, 0.1395230161472947, -1.31...
# 25    [-0.008853164333485361, 0.21733167502494177, 0...
# 26    [0.0696714227493704, 0.8118346011618767, 0.460...
# 27    [0.9781076023482898, 0.48474855626644603, -0.9...
# 28    [0.03131354788390277, 0.4560385924856003, -0.5...
# 29    [-0.11278734179064195, 0.029225555888290594, -...
# ...                                                 ...
# 1374  [0.5150799830750424, 0.17011258567823231, -0.2...
# 1375  [0.2605113479928373, -0.8439089911841624, -0.4...
# 1376  [0.1152120245908209, -0.17235801116565305, -1....
# 1377  [0.4377683430920497, -0.10688133839613319, 0.5...
# 1378  [-0.1998353076701931, -0.7732529840598711, -0....
# 1379  [-0.15665998052443, -0.6396039192174536, -0.58...
# 1380  [0.25433337674597356, -0.35130491283827014, -0...
# 1381  [0.03721929649621872, -0.5487499662356609, -0....
# 1382  [-0.27934585828070296, -0.6382112624379034, -0...
# 1383  [0.08096582907069126, 0.16376919347176902, -0....
# 1384  [0.07049873462116354, -0.4273810909360484, -0....
# 1385  [-0.12189992796569435, -0.48677416205530316, -...
# 1386  [-0.2445526692891163, -0.48994030771157215, -0...
# 1387  [-0.04724263604395809, -0.47828168763366813, -...
# 1388  [-0.03946891750617854, -0.6038705886413963, -0...
# 1389  [-0.017089344455002077, -0.46655079211614015, ...
# 1390  [0.012662636292114948, -0.5851094485305331, 0....
# 1391  [-0.06963262832443103, -0.7333754274031732, -0...
# 1392  [-0.2883424135113961, -0.6521787156254901, -0....
# 1393  [0.4851582274185451, -0.33431062278732016, 0.3...
# 1394  [-0.41398418166211914, -0.6390979816505755, -0...
# 1395  [-0.18012429805944571, -0.5107724017411268, -0...
# 1396  [0.4436266818709924, -0.21387678200082344, 0.0...
# 1397  [0.7417383874169693, -0.46499910600075073, -1....
# 1398  [0.059810002498323786, -0.05162625178496159, 0...
# 1399  [0.1821639099274571, -0.46001283462600356, 0.0...
# 1400  [0.045321151697339405, 0.25587199255037035, -0...
# 1401  [-0.11681505772341426, -0.3849588402290992, 0....
# 1402  [-0.3073219832178997, 0.17909744849978285, 0.2...
# 1403  [-0.11243018016255862, -0.5757785891988177, -0...
#
# [1404 rows x 10 columns]

# %% [markdown]
# ### How to remove unnamed?

# %%
### WILL NOT NEED THIS EVENTUALLY
### DO NOT NEED AS OF 9/7/2018
### all_train_data.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1)
# Out:
#                     file  language       start questions  \
# 0     p338p339-part1_ch2   English    3.717534        WH
# 1     p338p339-part1_ch2   English   42.674246        WH
# 2     p338p339-part1_ch2   English   53.887837        WH
# 3     p338p339-part1_ch2   English   80.117198        WH
# 4     p338p339-part1_ch2   English   83.519884        WH
# 5     p338p339-part1_ch2   English  113.454951        WH
# 6     p338p339-part1_ch2   English  129.659649        WH
# 7     p338p339-part1_ch2   English  139.157469       Y/N
# 8     p338p339-part1_ch2   English  150.003108        WH
# 9     p338p339-part1_ch2   English  171.926932       Y/N
# 10    p338p339-part1_ch2   English  211.085324       Y/N
# 11    p338p339-part1_ch2   English  226.222908       Y/N
# 12    p338p339-part1_ch2   English  243.681801       Y/N
# 13    p338p339-part1_ch2   English  255.429284       Y/N
# 14    p338p339-part1_ch2   English  262.821732        WH
# 15    p338p339-part1_ch2   English  265.870896        WH
# 16    p338p339-part1_ch2   English  290.015194        WH
# 17    p338p339-part1_ch2   English  310.986002       Y/N
# 18    p338p339-part1_ch2   English  320.332981       Y/N
# 19    p338p339-part1_ch2   English  353.217713        WH
# 20    p338p339-part1_ch2   English  364.712680        WH
# 21    p338p339-part1_ch2   English  412.712680        WH
# 22    p338p339-part1_ch2   English  468.688687        WH
# 23    p338p339-part1_ch2   English  485.534326        WH
# 24    p338p339-part1_ch2   English  525.472079        WH
# 25    p338p339-part1_ch2   English  540.293049        WH
# 26    p338p339-part1_ch2   English  546.177613        WH
# 27    p338p339-part1_ch2   English  554.988690       Y/N
# 28    p338p339-part1_ch2   English  571.207985       Y/N
# 29    p338p339-part1_ch2   English  577.366710       Y/N
# ...                  ...       ...         ...       ...
# 1171  p382p383-part2_ch1  Mandarin  455.979525       Y/N
# 1172  p382p383-part2_ch1  Mandarin  481.321037        WH
# 1173  p382p383-part2_ch1  Mandarin  497.560971       Y/N
# 1174  p382p383-part2_ch1  Mandarin  506.072285        WH
# 1175  p382p383-part2_ch1  Mandarin  520.783765        WH
# 1176  p382p383-part2_ch1  Mandarin  530.841253        WH
# 1177  p382p383-part2_ch1  Mandarin  556.440336        WH
# 1178  p382p383-part2_ch1  Mandarin  571.725112        WH
# 1179  p382p383-part2_ch1  Mandarin  576.769203        WH
# 1180  p382p383-part2_ch1  Mandarin  613.999652       Y/N
# 1181  p382p383-part2_ch1  Mandarin  631.548903       Y/N
# 1182  p382p383-part2_ch1  Mandarin  636.883512        WH
# 1183  p382p383-part2_ch1  Mandarin  638.192829        WH
# 1184  p382p383-part2_ch1  Mandarin  646.038752        WH
# 1185  p382p383-part2_ch1  Mandarin  657.029933        WH
# 1186  p382p383-part2_ch1  Mandarin  678.435256       Y/N
# 1187  p382p383-part2_ch1  Mandarin  716.152392        WH
# 1188  p382p383-part2_ch1  Mandarin  726.682093        WH
# 1189  p382p383-part2_ch1  Mandarin  735.204889       Y/N
# 1190  p382p383-part2_ch1  Mandarin  746.560962        WH
# 1191  p382p383-part2_ch1  Mandarin  765.882260       Y/N
# 1192  p382p383-part2_ch1  Mandarin  814.118364        WH
# 1193  p382p383-part2_ch1  Mandarin  861.839328        WH
# 1194  p382p383-part2_ch1  Mandarin  873.774936        WH
# 1195  p382p383-part2_ch1  Mandarin  941.588661        WH
# 1196  p382p383-part2_ch1  Mandarin  951.088079        WH
# 1197  p382p383-part2_ch1  Mandarin  962.830508        WH
# 1198  p382p383-part2_ch1  Mandarin  971.824766       Y/N
# 1199  p382p383-part2_ch1  Mandarin  977.800807        WH
# 1200  p382p383-part2_ch1  Mandarin  997.496480        WH
#
#                                                 f0final  \
# 0     [   0.         0.         0.         0.       ...
# 1     [  46.78357   45.69165   44.63128    0.       ...
# 2     [  92.46291   89.45504   94.97237  138.3255   ...
# 3     [   0.       120.7277   120.671    160.4208   ...
# 4     [   0.       288.0923   270.5072   253.9005   ...
# 5     [   0.         0.         0.       265.4231   ...
# 6     [ 245.951    247.0557   248.4736   249.1471   ...
# 7     [ 231.295    231.0795   230.7417   230.3866   ...
# 8     [ 158.9163   185.0209   212.0297   240.9215   ...
# 9     [   0.         0.         0.         0.       ...
# 10    [ 267.0957  271.3864  275.4627  273.0534  267....
# 11    [  71.43871   60.9293    49.82573   47.96315  ...
# 12    [ 200.1852   207.4494   217.4594   225.803    ...
# 13    [   0.         0.         0.         0.       ...
# 14    [   0.         0.         0.         0.       ...
# 15    [   0.         0.         0.         0.       ...
# 16    [   0.         0.         0.         0.       ...
# 17    [   0.         0.         0.        56.19998  ...
# 18    [ 180.5381   231.7659   281.9593   275.4341   ...
# 19    [  63.66607   57.12719   51.87626   45.39149  ...
# 20    [   0.         0.         0.        64.90453  ...
# 21    [   0.         0.         0.         0.       ...
# 22    [ 262.6671   261.4178   259.2343   256.4698   ...
# 23    [   0.       129.8389   130.4005   155.0076   ...
# 24    [ 262.8592   265.1808   267.357    267.1855   ...
# 25    [   0.       192.6487   210.1898   246.5324   ...
# 26    [ 223.2568   222.9218   222.3657   222.2951   ...
# 27    [  43.43847   43.31062    0.         0.       ...
# 28    [   0.         0.         0.         0.       ...
# 29    [   0.         0.         0.         0.       ...
# ...                                                 ...
# 1171  [   0.         0.         0.         0.       ...
# 1172  [   0.         0.       116.8152   116.3208   ...
# 1173  [   0.         0.         0.         0.       ...
# 1174  [   0.         0.         0.         0.       ...
# 1175  [  45.98798   47.10559   51.08163   62.9753   ...
# 1176  [   0.         0.         0.        70.82341  ...
# 1177  [   0.         0.       116.5184   116.6524   ...
# 1178  [   0.         0.         0.         0.       ...
# 1179  [  53.39452   51.24586    0.         0.       ...
# 1180  [   0.         0.         0.         0.       ...
# 1181  [   0.         0.         0.         0.       ...
# 1182  [ 234.5705   230.3843   224.1309   217.9264   ...
# 1183  [   0.         0.         0.         0.       ...
# 1184  [   0.         0.         0.         0.       ...
# 1185  [   0.         0.        58.07867   65.75446  ...
# 1186  [   0.         0.       247.9278   241.978    ...
# 1187  [  88.54507   88.92222   86.6314    84.22952  ...
# 1188  [  46.62912   50.71087   55.77507    0.       ...
# 1189  [  87.65512  123.6344   158.7374   193.6595   ...
# 1190  [   0.         0.         0.        47.81179  ...
# 1191  [   0.         0.         0.         0.       ...
# 1192  [   0.         0.         0.         0.       ...
# 1193  [   0.        0.      246.3453  243.0756  237....
# 1194  [   0.        67.56277   67.55511   66.96973  ...
# 1195  [   0.         0.         0.         0.       ...
# 1196  [   0.         0.         0.         0.       ...
# 1197  [   0.         0.         0.         0.       ...
# 1198  [   0.         0.         0.         0.       ...
# 1199  [   0.         0.         0.         0.       ...
# 1200  [   0.        0.        0.      272.2958  267....
#
#                                             legen_coefs
# 0     [211.42829075242244, -46.975671560762414, -37....
# 1     [166.54473954080404, -37.885317785642378, 28.6...
# 2     [102.5839477389969, -56.563885710815029, -36.3...
# 3     [171.58232229681471, -56.720512463943869, -32....
# 4     [120.00384115413456, -107.31155246726928, -10....
# 5     [151.7285179778909, -42.959382257593539, -12.5...
# 6     [172.00497291198849, -42.1394390467552, 29.659...
# 7     [86.222579084683545, -98.853289473117499, 27.6...
# 8     [172.36262067921987, -111.73595701017985, -37....
# 9     [125.86734414245046, -80.963372990056044, -8.3...
# 10    [182.48360510519643, -18.688613273717383, 74.3...
# 11    [120.19335887336035, -49.047571959606948, -55....
# 12    [191.74480980025706, -33.017993727720231, 25.4...
# 13    [178.69925932904496, 7.8829479223570873, 4.968...
# 14    [145.57644284041797, -82.520123619454537, -114...
# 15    [170.92654007317526, -53.04708562857568, -163....
# 16    [118.75685490863131, -45.490783977332981, -13....
# 17    [135.79964933746768, 19.920472089547879, -1.37...
# 18    [152.61816167803556, -90.227389702855959, -22....
# 19    [137.74711390610898, -75.419063695776998, -53....
# 20    [142.6720929771715, -60.172675973097476, -16.1...
# 21    [145.82604530948544, -45.194826688170913, 10.5...
# 22    [126.77518656763711, -63.698522161358319, -25....
# 23    [117.02488357806705, -12.641128807271786, 7.05...
# 24    [134.08803560448624, -78.048306714214959, -47....
# 25    [177.25118057030321, -51.058463392139906, 23.6...
# 26    [183.74421324688183, -8.6629111000391141, 65.2...
# 27    [156.87941551356229, -39.036747153386088, -58....
# 28    [126.38215392704595, -70.133955423806583, -63....
# 29    [131.98545549509106, -94.228959902062044, -48....
# ...                                                 ...
# 1171  [128.01361195035435, 9.591770437037896, 5.4680...
# 1172  [141.67307889447022, -28.957781432406769, -2.1...
# 1173  [115.39931119679656, -32.074133087580961, -123...
# 1174  [157.39015815233981, -19.202083017419096, -26....
# 1175  [106.92605453195318, -35.275338228793871, -12....
# 1176  [137.89736978682583, -9.2690053539675716, -22....
# 1177  [176.46224639460493, -26.643594317287484, -69....
# 1178  [166.56343388841768, 1.0454439460985818, -43.8...
# 1179  [158.59756377285174, 74.518947412701749, -70.9...
# 1180  [171.63574912056993, -14.590731699885783, 23.2...
# 1181  [103.96286737858345, -21.62650429395044, 40.57...
# 1182  [157.05251308962886, -99.69965094105001, -37.7...
# 1183  [127.9383317175144, -56.841632193940157, -86.8...
# 1184  [162.23293056315924, -2.9927117030728425, -116...
# 1185  [119.07824800219365, -73.988034908323087, -18....
# 1186  [162.375360001959, 50.82858003699635, 33.66063...
# 1187  [132.39343012948137, -2.2631502886034038, -45....
# 1188  [188.19962184670271, 37.037827388710312, -29.0...
# 1189  [146.48846032192063, -93.318251352972055, -67....
# 1190  [142.13288533868402, -69.700769857271226, -29....
# 1191  [156.69683414770768, -11.947989324969583, -20....
# 1192  [105.22330935926671, -6.6950519390319929, -41....
# 1193  [147.42676148453117, -12.160958088405398, 4.91...
# 1194  [191.27855149383973, 23.904424280563653, -58.6...
# 1195  [147.43319462771072, -25.191117795677119, -119...
# 1196  [100.56572488267973, -54.040617114540225, 87.9...
# 1197  [176.56803423442867, -33.509580158642848, -61....
# 1198  [118.21421559115733, -28.363924822029173, 49.5...
# 1199  [147.30661218070858, -29.409907832974234, -91....
# 1200  [207.39781503749268, -27.272282420649717, -24....
#
# [1201 rows x 6 columns]

# %% [markdown]
# ### How to get normal distributions of the legendre polynomials?
# Group by language & question type
# for each of the 4 categories
#     - get each legendre polynomial
#     - collect each individual polynomials - every first polynomial, every second poly nomial, etc. (into 8 different lists, one all [1,1,1,1,1 etc], one all [2,2,2,2,2 etc] and so on)
#     - get the average and standard deviation of each list, and end up with a list of [avg 1, avg 2, etc] and [std 1, std2, et] for each of the 4 language:question pairs

# %%
coeffs = []
for i, row in all_train_data.iterrows():
    leges = np.fromstring(row["legen_coefs"][1:-1], dtype=float, sep=",")
    coeffs.append(leges)

# %% [markdown]
# `range(x)` where `x` is the degree of polynomial

# %%
[[f'lg_{n}' for n in range(7)]]
# Out:
# [['lg_0', 'lg_1', 'lg_2', 'lg_3', 'lg_4', 'lg_5', 'lg_6']]

# %%
[[f'lg_{n}' for n in range(3)]]
# Out:
# [['lg_0', 'lg_1', 'lg_2']]

# %%
#df_coeff = pd.DataFrame(coeffs, columns = [f'lg{n}' for n in range(7)])
df_coeff = pd.DataFrame(coeffs, columns = [f'lg{n}' for n in range(3)])

# %%
all_train_data['legen_coefs']
# Out:
# 0       [25.779162970855815, -28.464634615630736, -78....
# 1       [26.437091310342687, 27.98981277873526, -25.76...
# 2       [-6.072831522520062, -46.63825117042612, 12.35...
# 3       [-4.10456046528124, 23.521095179131102, 0.3813...
# 4       [12.388804447970086, -27.830056954684732, -7.9...
# 5       [-7.8726008954355455, 15.20111327420836, -42.0...
# 6       [-8.920308020014152, -30.798990129495085, -47....
# 7       [-17.1817753277721, -10.309594224505258, -82.4...
# 8       [12.332217359329617, 3.6024354332275967, -9.82...
# 9       [-16.872246176201397, 10.886794889262335, -35....
# 10      [-2.9558409706308546, 3.571663615863053, -39.3...
# 11      [0.30816616738870867, 31.09669605045017, -104....
# 12      [-29.643076164662205, 3.7438607075878894, -45....
# 13      [6.430791815351011, 53.4556559041199, 66.30276...
# 14      [24.19953260580802, 11.803498410703371, -74.59...
# 15      [4.01603837554872, 4.223840028087748, -53.7098...
# 16      [14.66714746519441, 28.491558817512924, -5.844...
# 17      [7.48663753159732, 2.630942573560138, -91.4943...
# 18      [-32.910856271923954, 16.66073789120766, -31.8...
# 19      [15.672331462696773, 13.881992042917, -45.6902...
# 20      [-24.71142385064498, -1.4725202339920351, -37....
# 21      [7.98834197517539, -35.82434351574637, -34.051...
# 22      [37.252871683368994, 8.30493843677953, -73.904...
# 23      [19.158641316925245, 4.363621513918879, -90.92...
# 24      [50.0216148687413, 8.196066328040747, -77.5201...
# 25      [-0.5200656070061418, 12.766817066283433, 7.73...
# 26      [4.092741239382956, 47.68998278747622, 27.0576...
# 27      [57.45743610036819, 28.475813018458883, -57.22...
# 28      [1.8394665089387419, 26.789290078221956, -32.0...
# 29      [-6.625520002357738, 1.7168106105261913, -59.0...
#                               ...
# 1374    [29.90514189024651, 9.876603982256903, -12.827...
# 1375    [15.125085582323745, -48.99669750924508, -27.9...
# 1376    [6.689120245543762, -10.006971633906549, -79.0...
# 1377    [25.416488400638528, -6.205447105653358, 34.19...
# 1378    [-11.6022820278549, -44.894464869891124, -26.2...
# 1379    [-9.095556224335148, -37.13490445415385, -34.0...
# 1380    [14.766397392524249, -20.3964891092056, -34.80...
# 1381    [2.160923311642258, -31.85999483917066, -17.39...
# 1382    [-16.218602552643016, -37.05404788825087, -44....
# 1383    [4.7008128566299465, 9.508311580624257, -44.48...
# 1384    [4.0931015205715875, -24.813412645813433, -11....
# 1385    [-7.077414696732719, -28.261728009407125, -24....
# 1386    [-14.19853714960627, -28.445551955603914, -37....
# 1387    [-2.7428705843208894, -27.768661571333066, -31...
# 1388    [-2.2915345520040153, -35.06025516433384, -28....
# 1389    [-0.9921940038770004, -27.087574931435583, 0.7...
# 1390    [0.7351827822405416, -33.970998009186516, 4.44...
# 1391    [-4.042816064770528, -42.57920504765085, -16.8...
# 1392    [-16.740935529146725, -37.864987321241664, -44...
# 1393    [28.167908105369094, -19.409813889828676, 20.9...
# 1394    [-24.03559854721652, -37.105530113814, -28.078...
# 1395    [-10.457876190746262, -29.655047079264097, -10...
# 1396    [25.75661897876609, -12.417519070676994, 3.237...
# 1397    [43.06475198029478, -26.997485246387505, -59.9...
# 1398    [3.4725220741489657, -2.9973798936476417, 24.0...
# 1399    [10.576294464306104, -26.70798622125605, 1.507...
# 1400    [2.63131070258118, 14.855728225488777, -16.756...
# 1401    [-6.782191098290945, -22.35040987269075, 25.31...
# 1402    [-17.842874536172022, 10.39825810660962, 17.28...
# 1403    [-6.527608528714496, -33.42925559744152, -16.3...
# Name: legen_coefs, Length: 1404, dtype: object

# %%
df_coeff[['language', 'questions']] = all_train_data[['language', 'questions']]

# %%
df_coeff
# Out:
#             lg0        lg1         lg2  language questions
# 0     25.779163 -28.464635  -78.843826   English        WH
# 1     26.437091  27.989813  -25.765711   English       Y/N
# 2     -6.072832 -46.638251   12.357782   English        WH
# 3     -4.104560  23.521095    0.381337   English        WH
# 4     12.388804 -27.830057   -7.935668   English        WH
# 5     -7.872601  15.201113  -42.066840   English       Y/N
# 6     -8.920308 -30.798990  -47.622169   English       Y/N
# 7    -17.181775 -10.309594  -82.459577   English       Y/N
# 8     12.332217   3.602435   -9.823018   English       Y/N
# 9    -16.872246  10.886795  -35.256164   English        WH
# 10    -2.955841   3.571664  -39.372126   English        WH
# 11     0.308166  31.096696 -104.415041   English        WH
# 12   -29.643076   3.743861  -45.808542   English       Y/N
# 13     6.430792  53.455656   66.302764   English       Y/N
# 14    24.199533  11.803498  -74.595634   English        WH
# 15     4.016038   4.223840  -53.709885   English       Y/N
# 16    14.667147  28.491559   -5.844599   English       Y/N
# 17     7.486638   2.630943  -91.494362   English       Y/N
# 18   -32.910856  16.660738  -31.891453   English       Y/N
# 19    15.672331  13.881992  -45.690260   English       Y/N
# 20   -24.711424  -1.472520  -37.406031   English        WH
# 21     7.988342 -35.824344  -34.051823   English        WH
# 22    37.252872   8.304938  -73.904235   English       Y/N
# 23    19.158641   4.363622  -90.923351   English       Y/N
# 24    50.021615   8.196066  -77.520121   English        WH
# 25    -0.520066  12.766817    7.737895   English       Y/N
# 26     4.092741  47.689983   27.057656   English       Y/N
# 27    57.457436  28.475813  -57.224147   English        WH
# 28     1.839467  26.789290  -32.022265   English       Y/N
# 29    -6.625520   1.716811  -59.093242   English        WH
# ...         ...        ...         ...       ...       ...
# 1374  29.905142   9.876604  -12.827129  Mandarin        WH
# 1375  15.125086 -48.996698  -27.900452  Mandarin        WH
# 1376   6.689120 -10.006972  -79.034931  Mandarin        WH
# 1377  25.416488  -6.205447   34.190302  Mandarin        WH
# 1378 -11.602282 -44.894465  -26.219295  Mandarin       Y/N
# 1379  -9.095556 -37.134904  -34.004561  Mandarin       Y/N
# 1380  14.766397 -20.396489  -34.801206  Mandarin       Y/N
# 1381   2.160923 -31.859995  -17.397197  Mandarin       Y/N
# 1382 -16.218603 -37.054048  -44.039972  Mandarin       Y/N
# 1383   4.700813   9.508312  -44.486506  Mandarin       Y/N
# 1384   4.093102 -24.813413  -11.673442  Mandarin       Y/N
# 1385  -7.077415 -28.261728  -24.943400  Mandarin        WH
# 1386 -14.198537 -28.445552  -37.572039  Mandarin       Y/N
# 1387  -2.742871 -27.768662  -31.236559  Mandarin        WH
# 1388  -2.291535 -35.060255  -28.932353  Mandarin        WH
# 1389  -0.992194 -27.087575    0.728117  Mandarin        WH
# 1390   0.735183 -33.970998    4.442637  Mandarin        WH
# 1391  -4.042816 -42.579205  -16.809767  Mandarin        WH
# 1392 -16.740936 -37.864987  -44.804435  Mandarin        WH
# 1393  28.167908 -19.409814   20.915058  Mandarin       Y/N
# 1394 -24.035599 -37.105530  -28.078672  Mandarin       Y/N
# 1395 -10.457876 -29.655047  -10.548054  Mandarin       Y/N
# 1396  25.756619 -12.417519    3.237973  Mandarin        WH
# 1397  43.064752 -26.997485  -59.903104  Mandarin       Y/N
# 1398   3.472522  -2.997380   24.004164  Mandarin        WH
# 1399  10.576294 -26.707986    1.507573  Mandarin       Y/N
# 1400   2.631311  14.855728  -16.756207  Mandarin       Y/N
# 1401  -6.782191 -22.350410   25.311945  Mandarin       Y/N
# 1402 -17.842875  10.398258   17.288588  Mandarin       Y/N
# 1403  -6.527609 -33.429256  -16.356404  Mandarin       Y/N
#
# [1404 rows x 5 columns]

# %%
df_coeff_sorted = df_coeff.groupby(['language', 'questions'])

# %%
print(df_coeff_sorted)
# Out:
# <pandas.core.groupby.DataFrameGroupBy object at 0x0000009455759940>

# %%
df_sorted_stds = df_coeff.groupby(['language', 'questions']).std()
df_sorted_means = df_coeff.groupby(['language', 'questions']).mean()

# %%
df_sorted_means
# Out:
#                          lg0        lg1        lg2
# language questions
# English  WH        -0.616567  -9.102836 -40.700883
#          Y/N        2.871606  -5.799897 -29.152667
# Mandarin WH         1.043861 -13.056634 -26.392917
#          Y/N        2.855156 -12.762444 -12.895448

# %%
df_sorted_stds
# Out:
#                           lg0        lg1        lg2
# language questions
# English  WH         22.529471  39.137057  46.270271
#          Y/N        18.674958  38.797689  48.845837
# Mandarin WH         23.188898  43.325246  45.206917
#          Y/N        20.393394  33.374328  40.913169

# %%
df_means_idx = df_sorted_means.reset_index()
df_std_idx = df_sorted_stds.reset_index()

# %%
df_std_idx
# Out:
#    language questions        lg0        lg1        lg2
# 0   English        WH  22.529471  39.137057  46.270271
# 1   English       Y/N  18.674958  38.797689  48.845837
# 2  Mandarin        WH  23.188898  43.325246  45.206917
# 3  Mandarin       Y/N  20.393394  33.374328  40.913169

# %%
import matplotlib.pyplot as plt
x = np.linspace(-1,1, 100)
fig, ax = plt.subplots()
for (_, mean_row), (_, std_row) in zip(df_means_idx.iterrows(), df_std_idx.iterrows()):
    assert mean_row['language'] == std_row['language']
    assert mean_row['questions'] == std_row['questions']
    label = f"{mean_row['language']}: {mean_row['questions']}"
    fmean = np.poly1d(mean_row[2:].values)
    fstd = np.poly1d(std_row[2:].values)
    mean_line = fmean(x)
    std_line = fstd(x)
    _ = ax.plot(x, mean_line, label=label)
    _ = ax.fill_between(x, mean_line+std_line, mean_line-std_line, alpha=0.25)
_ = ax.legend(loc = "upper left")

# %%
from scipy.stats import norm

# %%
curve_probs = []
for i, row in df_coeff.iterrows():
    results = {'id':i, 'language': row['language'], 'questions':row['questions']}
    question_coeffs = row[:-2].values
    for (_, mean_row), (_, std_row) in zip(df_means_idx.iterrows(), df_std_idx.iterrows()):
        assert mean_row['language'] == std_row['language']
        assert mean_row['questions'] == std_row['questions']
        label = f"{mean_row['language']}: {mean_row['questions']}"
        mean_coeffs = mean_row[2:].values
        std_coeffs = std_row[2:].values
        log_sum = 0
        for qc, mc, stdc in zip(question_coeffs, mean_coeffs, std_coeffs):
            log_prob = norm.logpdf(qc, mc, stdc)
            log_sum +=log_prob
        final_prob = np.exp(log_sum)
        results[label] = final_prob
    curve_probs.append(results)

# %%
df_final_probs = pd.DataFrame(curve_probs)

# %%
df_final_probs
# Out:
#        English: WH  English: Y/N  Mandarin: WH  Mandarin: Y/N    id  language  \
# 0     4.935246e-07  4.248855e-07  3.790100e-07   2.960132e-07     0   English
# 1     4.584544e-07  5.524792e-07  4.899636e-07   5.276567e-07     1   English
# 2     4.943989e-07  6.406325e-07  6.839739e-07   1.023046e-06     2   English
# 3     7.325135e-07  1.047435e-06  8.014092e-07   1.130194e-06     3   English
# 4     9.143717e-07  1.220274e-06  1.076670e-06   1.832554e-06     4   English
# 5     1.217968e-06  1.268114e-06  9.883747e-07   1.084021e-06     5   English
# 6     1.233100e-06  1.111881e-06  1.049803e-06   1.163327e-06     6   English
# 7     7.899918e-07  5.519436e-07  4.747720e-07   3.306757e-07     7   English
# 8     1.001771e-06  1.416938e-06  1.078369e-06   1.809821e-06     8   English
# 9     1.045649e-06  9.280304e-07  8.734022e-07   9.569104e-07     9   English
# 10    1.468233e-06  1.623746e-06  1.227885e-06   1.575361e-06    10   English
# 11    3.555386e-07  3.450057e-07  1.874750e-07   7.816204e-08    11   English
# 12    6.391437e-07  3.607400e-07  4.926285e-07   4.100947e-07    12   English
# 13    2.849153e-08  8.131043e-08  5.117164e-08   4.816860e-08    13   English
# 14    5.625214e-07  5.469694e-07  4.079456e-07   3.225416e-07    14   English
# 15    1.382181e-06  1.526306e-06  1.066851e-06   1.215935e-06    15   English
# 16    5.868955e-07  8.874181e-07  6.698743e-07   8.848680e-07    16   English
# 17    7.634874e-07  7.526702e-07  4.466292e-07   3.156080e-07    17   English
# 18    4.404981e-07  2.416371e-07  3.754472e-07   2.981747e-07    18   English
# 19    1.002668e-06  1.177712e-06  8.621256e-07   9.868874e-07    19   English
# 20    8.597315e-07  5.904989e-07  7.066775e-07   7.217858e-07    20   English
# 21    1.134227e-06  1.274403e-06  1.147704e-06   1.522148e-06    21   English
# 22    2.653313e-07  2.027055e-07  2.105782e-07   1.481858e-07    22   English
# 23    5.536733e-07  5.327247e-07  3.431033e-07   2.356038e-07    23   English
# 24    8.225470e-08  4.250742e-08  7.027491e-08   3.706701e-08    24   English
# 25    7.696657e-07  1.183275e-06  8.782058e-07   1.478185e-06    25   English
# 26    1.818316e-07  3.569423e-07  2.578081e-07   2.739276e-07    26   English
# 27    3.321752e-08  1.436886e-08  3.628966e-08   1.639993e-08    27   English
# 28    9.982455e-07  1.256648e-06  9.082609e-07   1.011569e-06    28   English
# 29    1.335781e-06  1.282155e-06  9.613564e-07   9.846831e-07    29   English
# ...            ...           ...           ...            ...   ...       ...
# 1374  4.609783e-07  5.484001e-07  5.354662e-07   7.516325e-07  1374  Mandarin
# 1375  6.979627e-07  7.780814e-07  8.236912e-07   9.867177e-07  1375  Mandarin
# 1376  1.047355e-06  1.036931e-06  6.872427e-07   6.044093e-07  1376  Mandarin
# 1377  2.148297e-07  3.733995e-07  3.237467e-07   6.254634e-07  1377  Mandarin
# 1378  8.661178e-07  7.982381e-07  9.197221e-07   1.058083e-06  1378  Mandarin
# 1379  1.110155e-06  1.049252e-06  1.073402e-06   1.287611e-06  1379  Mandarin
# 1380  1.172847e-06  1.355511e-06  1.136884e-06   1.622836e-06  1380  Mandarin
# 1381  1.148915e-06  1.389873e-06  1.245948e-06   1.923012e-06  1381  Mandarin
# 1382  9.463673e-07  7.342421e-07  8.422832e-07   8.455535e-07  1382  Mandarin
# 1383  1.347207e-06  1.572348e-06  1.112795e-06   1.349045e-06  1383  Mandarin
# 1384  1.153845e-06  1.489190e-06  1.266888e-06   2.131371e-06  1384  Mandarin
# 1385  1.250286e-06  1.311628e-06  1.235666e-06   1.740969e-06  1385  Mandarin
# 1386  1.145873e-06  9.816935e-07  1.025671e-06   1.199971e-06  1386  Mandarin
# 1387  1.354178e-06  1.459459e-06  1.294738e-06   1.794992e-06  1387  Mandarin
# 1388  1.205924e-06  1.299345e-06  1.214275e-06   1.636223e-06  1388  Mandarin
# 1389  9.377554e-07  1.252874e-06  1.103826e-06   1.932649e-06  1389  Mandarin
# 1390  7.887404e-07  1.080910e-06  9.859047e-07   1.694070e-06  1390  Mandarin
# 1391  9.338983e-07  1.035291e-06  1.057961e-06   1.438179e-06  1391  Mandarin
# 1392  9.159526e-07  6.977824e-07  8.138757e-07   7.989744e-07  1392  Mandarin
# 1393  2.738419e-07  3.986040e-07  4.035839e-07   7.353757e-07  1393  Mandarin
# 1394  6.762834e-07  4.587377e-07  6.672653e-07   6.838755e-07  1394  Mandarin
# 1395  9.966830e-07  1.070569e-06  1.080275e-06   1.618373e-06  1395  Mandarin
# 1396  4.979131e-07  6.697983e-07  6.390613e-07   1.122878e-06  1396  Mandarin
# 1397  1.963383e-07  1.250526e-07  1.952756e-07   1.540361e-07  1397  Mandarin
# 1398  5.688602e-07  9.892613e-07  7.270193e-07   1.453929e-06  1398  Mandarin
# 1399  8.200810e-07  1.170193e-06  1.010506e-06   1.828153e-06  1399  Mandarin
# 1400  1.116984e-06  1.507532e-06  1.107873e-06   1.611768e-06  1400  Mandarin
# 1401  5.116363e-07  7.696918e-07  6.709972e-07   1.265243e-06  1401  Mandarin
# 1402  4.678974e-07  5.656206e-07  5.433435e-07   8.156712e-07  1402  Mandarin
# 1403  1.079284e-06  1.185231e-06  1.157809e-06   1.687242e-06  1403  Mandarin
#
#      questions
# 0           WH
# 1          Y/N
# 2           WH
# 3           WH
# 4           WH
# 5          Y/N
# 6          Y/N
# 7          Y/N
# 8          Y/N
# 9           WH
# 10          WH
# 11          WH
# 12         Y/N
# 13         Y/N
# 14          WH
# 15         Y/N
# 16         Y/N
# 17         Y/N
# 18         Y/N
# 19         Y/N
# 20          WH
# 21          WH
# 22         Y/N
# 23         Y/N
# 24          WH
# 25         Y/N
# 26         Y/N
# 27          WH
# 28         Y/N
# 29          WH
# ...        ...
# 1374        WH
# 1375        WH
# 1376        WH
# 1377        WH
# 1378       Y/N
# 1379       Y/N
# 1380       Y/N
# 1381       Y/N
# 1382       Y/N
# 1383       Y/N
# 1384       Y/N
# 1385        WH
# 1386       Y/N
# 1387        WH
# 1388        WH
# 1389        WH
# 1390        WH
# 1391        WH
# 1392        WH
# 1393       Y/N
# 1394       Y/N
# 1395       Y/N
# 1396        WH
# 1397       Y/N
# 1398        WH
# 1399       Y/N
# 1400       Y/N
# 1401       Y/N
# 1402       Y/N
# 1403       Y/N
#
# [1404 rows x 7 columns]

# %% [markdown]
# df_final_probs.to_csv("C:/Users/Rachel/Documents/Grad_Stuff/Dissertation/results/final_probs_3deg.csv", index=False)

# %%
#import statsmodels.api as sm
from matplotlib.lines import Line2D
fig, ax = plt.subplots()
c = ['tab:blue', 'tab:orange', 'tab:green', 'tab:pink']

legend_elements = []
i = 0
for ((language, question), dfgroup) in df_coeff.groupby(['language', 'questions']):
    for _, row in dfgroup.iterrows():
        f = np.poly1d(row[:-2].values)
        _ = ax.plot(x, f(x), color=c[i], alpha=.75, linewidth=.25)
    legend_elements.append(Line2D([0],[0], color=c[i], lw=4, label=f'{language}: {question}'))
    i+=1
_ = ax.legend(handles=legend_elements)

ax.set_xlim(-1,1)
ax.set_ylim(-300,500)
# Out:
# (-300, 500)

# %%
from matplotlib.lines import Line2D
import matplotlib.cm as mcm

c = ['tab:blue', 'tab:orange', 'tab:green', 'tab:pink']
legend_elements = []
i = 0
fig, axes = plt.subplots(nrows=2, ncols=2)
for ((language, question), dfgroup) in df_coeff.groupby(['language', 'questions']):
    ax = axes.flatten()[i]
    ax.set_title(f'{language}: {question}')
    for _, row in dfgroup.iterrows():
        f = np.poly1d(row[:-2].values)
        _ = ax.plot(x, f(x),color=mcm.tab20(np.random.randint(0,20)), alpha=.75, linewidth=.25)

    i+=1
    ax.set_xlim(-1,1)
    ax.set_ylim(-300,500)
plt.tight_layout()

# %%
list(zip([1,2,3,4], [2,3,4,5]))
# Out:
# [(1, 2), (2, 3), (3, 4), (4, 5)]

# %% [markdown]
# ## to write things out
# df_sorted_means.reset_index().to_csv("c:/Users/Rachel/Documents/Grad_Stuff/Dissertation/test_sorted_means.csv", header = True, index=False)
# df_sorted_stds.reset_index().to_csv("C:/Users/Rachel/Documents/Grad_Stuff/Dissertation/test_sorted_stds.csv", header = True, index=False)

# %%
df_sorted_means
# Out:
#                            lg0        lg1        lg2        lg3        lg4  \
# language questions
# English  WH         116.055174 -15.436988 -34.653145  21.605102 -31.474165
#          Y/N        119.903705 -10.782847 -22.558493  28.061637 -41.210035
# Mandarin WH         115.354837 -15.658551 -22.281550  11.435644 -28.985782
#          Y/N        113.076393 -14.245831 -11.523809  20.101706 -36.669359
#
#                           lg5        lg6
# language questions
# English  WH         15.228626  -9.580283
#          Y/N         9.898523 -21.802439
# Mandarin WH          8.016178 -19.969282
#          Y/N        14.400172 -26.467268

# %% [markdown]
# ## Analyses

# %%
sorted_means = []
for i, row in df_sorted_means.iterrows():
    means =list(row)
    sorted_means.append(means)

# %%
sorted_stds = []
for i, row in df_sorted_stds.iterrows():
    stds = list(row)
    sorted_stds.append(stds)

# %%
print (sorted_stds)
# Out:
# [[33.895231663727991, 41.216536242407038, 46.273252373337414, 49.757738983528213, 46.88632602636762, 50.838810476095411, 54.4167639805774], [34.149443449879108, 40.819797410761097, 48.942756320562737, 50.164232678508242, 51.142389166243348, 55.426787073442931, 54.589061790616924], [35.739081425430307, 42.09608987831993, 45.785707424043792, 49.852781549110773, 52.514880664693536, 54.333598281452247, 50.812336987967278], [36.347830956508666, 33.452702821820459, 40.492312317205034, 44.914769889820668, 48.052785370290977, 48.679633055304251, 47.646300075905387]]

# %%
import scipy.stats as stats
import pylab as pl
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import math

# %%
sorted_means[0][0]
# Out:
# 116.0551744452915

# %%
import pylab
import numpy as np
from scipy.stats import norm

# %% [markdown]
# #### To be done:
# ```For a specific contour c
# for the first coefficient a
# what is the probability that a comes from an English yes/no question?
# norm.pdf(a, meanEnglishYesnoCoef0, sdEnglishYesnoCoef0)```
#
# ```100 contours
# x 7 coefficients
# x 4 groups
# = 2800 probabilities
# sum log probabilities for each coefficient over each contour/group for 4 summed probabilities/scores per contour
# = 400 final probabilities```

# %% [markdown]
# ```q1:  114.818320 	-28.762645 	-78.101458 	2.296430 	-32.245774 	-4.196429 	9.642555 	English 	WH```

# %%
q1 = [114.818320, -28.762645, 78.101458, 2.296430, -32.245774, -4.196429,9.642555]

# %% [markdown]
# ```means:  116.055174 	-15.436988 	-34.653145 	21.605102 	-31.474165 	15.228626 	-9.580283```

# %%
means_list= [116.055174, -15.436988, -34.653145, 21.605102, -31.474165, 15.228626 ,-9.580283]

# %% [markdown]
# ```stds = 33.895231663727991, 41.216536242407038, 46.273252373337414, 49.757738983528213, 46.88632602636762, 50.838810476095411, 54.4167639805774```

# %%
stds_list = [33.895231663727991, 41.216536242407038, 46.273252373337414, 49.757738983528213, 46.88632602636762, 50.838810476095411, 54.4167639805774]

# %% [markdown]
# ```output pdf:  0.01176203088453448, 0.0091862978332215572, 0.0055480040739882544, 0.0074361847950384346, 0.0085075606136212258, 0.0072947864490794066, 0.0068877945738117889```

# %%
norm.pdf(9.642555, loc = -9.580283, scale=54.4167639805774 )
# Out:
# 0.0068877945738117889

# %%
from math import log

# %%
l = log(0.01176203088453448)
print (l)
# Out:
# -4.442878657158458

# %%
to_sum = []
for i in range(len(q1)):
    log = norm.logpdf(q1[i], means_list[i], stds_list[i])
    print(log)
    to_sum.append(log)
    
x = sum(to_sum)
print (x)
# Out:
# -4.44287865716
# -4.69004227109
# -7.72228602979
# -4.90139735803
# -4.76680002689
# -4.92059537104
# -4.97800433608
# -36.4220040501

# %% [markdown]
# ```After you sum up the log probabilities, you call exp
# exp(-36.4220040501) = 1.5e-16
# for the actual probability
# e.g. in this case close to zero```
